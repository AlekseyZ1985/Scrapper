# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df.head(50)
# Out:
#                                                  name  \
# 0                           1+1: Голливудская история
# 1                                    1 Night in China
# 2                                           2 секунды
# 3                                      2 дня в Париже
# 4                                    55 дней в Пекине
# 5                                       2 Girls 1 Cup
# 6                                                 NaN
# 7                                            2-Асса-2
# 8                                                 1+1
# 9                                         50 таблеток
# 10                                                2+1
# 11                                               2:37
# 12                                 50 первых поцелуев
# 13                                              01-99
# 14                                               2:22
# 15                                                 51
# ...

# %%
df.shape
# Out:
# (171, 6)
